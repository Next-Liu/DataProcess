# %%
import pandas as pd

df = pd.read_csv('../data/20200101-20201231/china_sites_20200101.csv')
df.head()
# Out:
#        date  hour       type  1001A  1002A  1003A  1004A  1005A  1006A  1007A  \
# 0  20200101     0        AQI    NaN    NaN   58.0    NaN    NaN    NaN   61.0
# 1  20200101     0      PM2.5    NaN    NaN   37.0    NaN    NaN    NaN   32.0
# 2  20200101     0  PM2.5_24h   25.0   13.0   24.0   23.0   23.0   20.0   22.0
# 3  20200101     0       PM10    NaN    NaN   66.0    NaN    NaN    NaN   71.0
# 4  20200101     0   PM10_24h   42.0   25.0   37.0   37.0   40.0   40.0   43.0
#
#    ...  3207A.1  3208A  3209A  3210A  3216A  3237A  3238A  3239A  3662A  3663A
# 0  ...     54.0  109.0   40.0   67.0   47.0   53.0    NaN   74.0   54.0   80.0
# 1  ...     38.0   82.0   27.0   48.0   24.0   19.0    NaN   54.0    NaN   14.0
# 2  ...     28.0   46.0   40.0   27.0   39.0   28.0    NaN   28.0    NaN   21.0
# 3  ...     48.0   87.0   40.0   71.0   47.0   56.0    NaN   76.0   57.0    6.0
# 4  ...     49.0   63.0   47.0   58.0   69.0   55.0    NaN   39.0   72.0   12.0
#
# [5 rows x 1644 columns]

# %%
print(df['date'])
print(df[0:5]['1036A'])
# Out:
# 0      20200101
# 1      20200101
# 2      20200101
# 3      20200101
# 4      20200101
#          ...
# 355    20200101
# 356    20200101
# 357    20200101
# 358    20200101
# 359    20200101
# Name: date, Length: 360, dtype: int64
# 0    65.0
# 1    42.0
# 2    33.0
# 3    80.0
# 4    51.0
# Name: 1036A, dtype: float64

# %%
temp_data = [20200101, 0]
temp_hour = 0
# 遍历df
for i in range(len(df)):
    hour = df.iloc[i]['hour']
    if hour == temp_hour:
        print('same hour')
        if df.iloc[i]['type'] == 'AQI':
            temp_data.append(df.iloc[i]['1036A'])
        if df.iloc[i]['type'] == 'PM2.5':
            value = df.iloc[i]['1036A']
            temp_data.append(value if value != '' else 0)
        if df.iloc[i]['type'] == 'PM10':
            value = df.iloc[i]['1036A']
            temp_data.append(value if value != '' else 0)
        if df.iloc[i]['type'] == 'SO2':
            value = df.iloc[i]['1036A']
            temp_data.append(value if value != '' else 0)
        if df.iloc[i]['type'] == 'NO2':
            value = df.iloc[i]['1036A']
            temp_data.append(value if value != '' else 0)
        if df.iloc[i]['type'] == 'O3':
            value = df.iloc[i]['1036A']
            temp_data.append(value if value != '' else 0)
        if df.iloc[i]['type'] == 'CO':
            value = df.iloc[i]['1036A']
            temp_data.append(value if value != '' else 0)
# Out:
# same hour
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-dcf7c708088c> in <module>
#       6     if hour == temp_hour:
#       7         print('same hour')
# ----> 8         if df.iloc[i]['type'] == 'AQI':
#       9             temp_data.append(df.iloc[i]['1036A'])
#      10         if df.iloc[i]['type'] == 'PM2.5':
#
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4742                     raise InvalidIndexError(key)
#    4743                 else:
# -> 4744                     raise e1
#    4745             except Exception:  # pragma: no cover
#    4746                 raise e1
#
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'

# %%
temp_data
# Out:
# [20200101, 0, 65.0, 42.0, 80.0, 16.0, 60.0, 5.0, 0.9]

# %%
l = [[20200101, 0, 65.0, 42.0, 80.0, 16.0, 60.0, 5.0, 0.9],[20200101, 0, 65.0, 42.0, 80.0, 16.0, 60.0, 5.0, 0.9]]

# %%
columns = ['date', 'hour', 'AQI', 'PM2.5', 'PM10', 'SO2', 'NO2', 'O3', 'CO']
# 将l的元素依次添加到dataframe中
for i in range(len(l)):
    df = df.append(pd.DataFrame([l[i]], columns=columns))
df.to_csv('1036A.csv', index=False)

# %%
import os

folder_path = '../data/20200101-20201231'
count = 0
# 列出文件夹中的所有文件和目录
for file_name in os.listdir(folder_path):
    count += 1
count
# Out:
# 366

# %%
import pandas as pd
import os

folderList = ['../data/20200101-20201231', '../data/20210101-20211231', '../data/20220101-20221231',
               '../data/20230101-20231231']
folderPath = '../data/20200101-20201231'
#folderPath = '../data/test'
df = pd.read_csv('../data/20200101-20201231/china_sites_20200101.csv')

final_data = []

# 遍历df
for fileName in os.listdir(folderPath):
    df = pd.read_csv(folderPath + '/' + fileName)
    temp_hour = 0
    temp_data = []
    print(fileName)
    for i in range(len(df)):
        date = df.iloc[i]['date']
        hour = df.iloc[i]['hour']
        if i == 0:
            temp_data = [date, hour]
        if hour == temp_hour:
            count += 1
            if df.iloc[i]['type'] == 'AQI':
                temp_data.append(df.iloc[i]['1037A'])
            if df.iloc[i]['type'] == 'PM2.5':
                value = df.iloc[i]['1037A']
                temp_data.append(value if value != '' else 0)
            if df.iloc[i]['type'] == 'PM10':
                value = df.iloc[i]['1037A']
                temp_data.append(value if value != '' else 0)
            if df.iloc[i]['type'] == 'SO2':
                value = df.iloc[i]['1037A']
                temp_data.append(value if value != '' else 0)
            if df.iloc[i]['type'] == 'NO2':
                value = df.iloc[i]['1037A']
                temp_data.append(value if value != '' else 0)
            if df.iloc[i]['type'] == 'O3':
                value = df.iloc[i]['1037A']
                temp_data.append(value if value != '' else 0)
            if df.iloc[i]['type'] == 'CO':
                value = df.iloc[i]['1037A']
                temp_data.append(value if value != '' else 0)
        if hour != temp_hour:
            final_data.append(temp_data)
            temp_hour += 1
            temp_data = [date, temp_hour]
            if df.iloc[i]['type'] == 'AQI':
                temp_data.append(df.iloc[i]['1037A'])
        if i == len(df) - 1:
            final_data.append(temp_data)
# Out:
# china_sites_20200101.csv
# china_sites_20200102.csv
# china_sites_20200103.csv
# china_sites_20200104.csv
# china_sites_20200105.csv
# china_sites_20200106.csv
# china_sites_20200107.csv
# china_sites_20200108.csv
# china_sites_20200109.csv
# china_sites_20200110.csv
# china_sites_20200111.csv
# china_sites_20200112.csv
# china_sites_20200113.csv
# china_sites_20200114.csv
# china_sites_20200115.csv
# china_sites_20200116.csv
# china_sites_20200117.csv
# china_sites_20200118.csv
# china_sites_20200119.csv
# china_sites_20200120.csv
# china_sites_20200121.csv
# china_sites_20200122.csv
# china_sites_20200123.csv
# china_sites_20200124.csv
# china_sites_20200125.csv
# china_sites_20200126.csv
# china_sites_20200127.csv
# china_sites_20200128.csv
# china_sites_20200129.csv
# china_sites_20200130.csv
# china_sites_20200131.csv
# china_sites_20200201.csv
# china_sites_20200202.csv
# china_sites_20200203.csv
# 3213 [20200513, 21, 95.0]
# 3214 [20200513, 22, 140.0, 18.0, 59.0, 108.0, 1.2]
# 3848 [20200609, 8, 71.0]
# 3849 [20200609, 9, 91.0, 21.0, 39.0, 59.0, 0.9]
# 6482 [20200927, 2, 73.0]
# 6483 [20200927, 3]
# 6484 [20200927, 4, 58.0, 6.0, 54.0, 10.0, 0.7]
# 6485 [20200927, 5, 79.0]
# 6486 [20200927, 6, 84.0, 6.0, 58.0, 4.0, 1.2]
# 7075 [20201021, 19, nan]
# 7076 [20201021, 20, 98.0, 5.0, 61.0, 14.0, nan]
# 7875 [20201124, 3, 95.0]
# 7876 [20201124, 4]
# 7877 [20201124, 5]
# 7878 [20201124, 6]
# 7879 [20201124, 7]
# 7880 [20201124, 8]
# 7881 [20201124, 9, 51.0, 9.0, 1.9]
# 8273 [20201210, 17, 78.0]
# 8274 [20201210, 18, 105.0, 13.0, 79.0, 9.0, 0.9]
# 8391 [20201215, 15, 39.0]
# 8392 [20201215, 16]
# 8393 [20201215, 17, 39.0, 8.0, 38.0, 34.0, 0.6]
# 8394 [20201215, 18, 69.0]
# 8395 [20201215, 19]
# 8396 [20201215, 20, 87.0, 18.0, 65.0, 7.0, 1.2]
# 8413 [20201216, 13, 52.0]
# 8414 [20201216, 14]
# 8415 [20201216, 15]
# 8416 [20201216, 16]
# 8417 [20201216, 17]
# 8418 [20201216, 18]
# 8419 [20201216, 19]
# 8420 [20201216, 20, 5.0, 0.7]
# 8434 [20201217, 10, 97.0]
# 8435 [20201217, 11, 140.0, 25.0, 72.0, 16.0, 1.2]
# 8721 [20201229, 9, 60.0]
# 8722 [20201229, 10, 69.0, 8.0, 16.0, 52.0, 0.5]
# 8723 [20201229, 11, 57.0]
# 8724 [20201229, 12, 64.0, 8.0, 14.0, 57.0, 0.4]

# %%
columns = ['date', 'hour', 'AQI', 'PM2.5', 'PM10', 'SO2', 'NO2', 'O3', 'CO']
# 将final_data的元素依次添加到dataframe中
new_df = pd.DataFrame(columns=columns)
for i in range(len(final_data)):
    new_df = new_df.append(pd.DataFrame([final_data[i]], columns=columns))
new_df.to_csv('1036A_2020.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     499         result = _convert_object_array(
# --> 500             content, columns, dtype=dtype, coerce_float=coerce_float
#     501         )
#
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\internals\construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     582                 "{col:d} columns passed, passed data had "
# --> 583                 "{con} columns".format(col=len(columns), con=len(content))
#     584             )
#
# AssertionError: 9 columns passed, passed data had 0 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-78678d05e38b> in <module>
#       3 new_df = pd.DataFrame(columns=columns)
#       4 for i in range(len(final_data)):
# ----> 5     new_df = new_df.append(pd.DataFrame([final_data[i]], columns=columns))
#       6 new_df.to_csv('1036A_2020.csv', index=False)
#
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     448                     if is_named_tuple(data[0]) and columns is None:
#     449                         columns = data[0]._fields
# --> 450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     451                     columns = ensure_index(columns)
#     452
#
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     462         return [], []  # columns if columns is not None else []
#     463     if isinstance(data[0], (list, tuple)):
# --> 464         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     465     elif isinstance(data[0], abc.Mapping):
#     466         return _list_of_dict_to_arrays(
#
# C:\Anaconda\envs\graduate\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     501         )
#     502     except AssertionError as e:
# --> 503         raise ValueError(e) from e
#     504     return result
#     505
#
# ValueError: 9 columns passed, passed data had 0 columns
